# %%
import copy

# %%
import stained_glass.idealized as idealized

# %% [markdown]
# ## Setup Idealized Projection

# %%
ip = idealized.IdealizedProjection()

# %%
ip.generate_sightlines( 1000, )

# %% [markdown]
# ## Idealized Projection Plots

# %%
ip.add_ellipse( (5., 5.), 2., value=5 )

# %%
ip.add_clumps(
    0.2,
    (-5., 5.),
    4.2,
    0.5,
    value = 5
)

# %%
ip.add_curve(
    v1 = (0., 0.),
    v2 = ( -10., -10.),
    theta_a = 20.,
    theta_b = 40.,
    value = 5,
)

# %%
# Add concentric structures around the circle
ip.add_concentric_structures(
    ip.structs[0],
    value=ip.struct_values[0],
)

# %%
# Add concentric structures around the clumps
ip.add_concentric_structures(
    ip.structs[1],
    value=ip.struct_values[1],
    n_concentric = 4,
    dr = 0.2,
)

# %%
# Add concentric structures around the clumps
ip.add_concentric_structures(
    ip.structs[2],
    value=ip.struct_values[2],
    n_concentric = 4,
    dr = 0.2,
)

# %%
ip.add_background()

# %%
fig = plt.figure( figsize=(10,10), facecolor='w' )
ax = plt.gca()

ip.plot_idealized_projection(
    ax,
)

# %%
fig = plt.figure( figsize=(10,10), facecolor='w' )
ax = plt.gca()

ip.plot_sightlines(
    ax,
)
